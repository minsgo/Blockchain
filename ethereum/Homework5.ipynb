# %% [markdown]
# # 컨트랙 '학생'을 구현하세요.
#
# 컨트랙의 이름은 'StudentsCrud.sol'로 명명하세요.
#
# 학생들을 배열로 구성하고, 다음 기능이 제공되도록 하자.
#
# * 입력: '학번', '이름', '등록여부'를 입력한다.
#
# * 검색: 조건에 해당하는 항목을 찾기 위해서는 반복문이 필수적이다.
#
# 그러나 gas비용이 급증할 수 있으므로, 배열의 인덱스로 검색하도록 하자.
#
# * 삭제: 배열에서는 어떤 항목의 데이터를 지우기 위해서는 검색이 필요하다.
#
# 그러나 역시 gas비용이 급증할 수 있으므로, 배열의 인덱스에 해당하는 항목을 지우기로 한다.
#
# 해당 항목을 지우고 나서는, 그 항목을 제거하고 배열의 크기도 같이 줄어야 한다.
#
#
#
# 함수의 시그니처는 다음과 같다.
#
# ```
#
# * 입력함수 - function insert(uint n, string memory sn, bool e) public
#
# * 첫 데이터 조회 - function getFirstStudent() public view returns(uint, string memory, bool)
#
# * 검색함수 - function findBy(uint8 index) view public returns(uint, string memory, bool)
#
# * 삭제함수 - function remove(uint index) public
#
# * 배열크기 조회함수 - function getLength() view public returns(uint)
#
# * 삭제함수 - function pop() public
#
# 컨트랙을 구현하고, REMIX에서 DEPLOY한 후, 제공되는 함수버튼을 활용하여 다음 작업을 수행해보자.
#
# 항목별 답안으로는 수행결과가 출력된 REMIX 단말의 로그를 붙여넣기 하면 된다.
#
# (선택적으로 노드에서 배포하고 실행해도 좋아요)
#
# (1) 아래 항목을 입력
#
# ```
#
# 201711111,"kim",false
#
# 201711112, "park", true
#
# 201711113, "lee", false
#
# 201711114, "lim", false
#
# ```
#
#
#
# (2) 2번째 데이터 201711112 제거
#
#
#
# (3) 배열크기 조회 (4개 항목에서 1개가 제거되었으니 3이 출력)
#
#
#
# (4) 2 번째 데이터조회를 조회한다. 20171112는 삭제되어서 출력할 수 없고, 다른 데이터 항목이 출력.
#
#
#
# (5) 첫 데이터 조회

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%writefile src/StudentsCrud
# pragma solidity ^0.6.4;
# contract StudentsCrud
# {
#     struct Student
#     {
#         uint num;
#         string name;
#         bool isEnrolled;
#     }
#
#     Student[] stu;
#
#     function insert(uint n, string memory sn, bool e) public
#     {
#         Student memory s;
#         s.num = n;
#         s.name = sn;
#         s.isEnrolled = e;
#         stu.push(s);
#     }
#
#     function getFirstStudent() public view returns(uint, string memory, bool)
#     {
#         return (stu[0].num, stu[0].name, stu[0].isEnrolled);
#     }
#
#     function findBy(uint8 index) view public returns(uint, string memory, bool)
#     {
#         return (stu[index].num, stu[index].name, stu[index].isEnrolled);
#     }
#
#     function remove(uint index) public
#     {
#         if(index < stu.length)
#         {
#             stu[index] = stu[index+1];
#             index++;
#         }
#         stu.pop();
#     }
#
#     function getLength() view public returns(uint)
#     {
#         return stu.length;
#     }
#
#     function pop() public
#     {
#         stu.pop();
#     }
# }
# Out:
# Writing src/StudentsCrud

# %% [markdown]
# ## (1) 아래 항목을 입력
# 201711111,"kim",false
#
# 201711112, "park", true
#
# 201711113, "lee", false
#
# 201711114, "lim", false

# %% [markdown]
# ### ![image-2.png](attachment:image-2.png)
# [vm]from: 0x5B3...eddC4to: StudentsCrud.insert(uint256,string,bool) 0x7EF...8CB47value: 0 weidata: 0xf07...00000logs: 0hash: 0xa78...6d4b9
#
# status	true Transaction mined and execution succeed
#
# transaction hash	0xa783ef2cc63fac7327d0fb2f34a38c9fc258013c4ae1532585cb974b2c46d4b9
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.insert(uint256,string,bool) 0x7EF2e0048f5bAeDe046f6BF797943daF4ED8CB47
#
# gas	105597 gas
#
# transaction cost	91823 gas
#
# execution cost	91823 gas
#
# input	0xf07...00000
#
# decoded input	{
# 	"uint256 n": "201711111",
# 	"string sn": "kim",
# 	"bool e": false
# }
#
# decoded output	{}
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# ### ![image.png](attachment:image.png)
# [vm]from: 0x5B3...eddC4to: StudentsCrud.insert(uint256,string,bool) 0x7EF...8CB47value: 0 weidata: 0xf07...00000logs: 0hash: 0xb24...6b77d
#
# status	true Transaction mined and execution succeed
#
# transaction hash	0xb24902c82c13bf205599f69f1ef79ca3038c5d343ab54b1d2cf1d431a3d6b77d
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.insert(uint256,string,bool) 0x7EF2e0048f5bAeDe046f6BF797943daF4ED8CB47
#
# gas	108845 gas
#
# transaction cost	94647 gas
#
# execution cost	94647 gas
#
# input	0xf07...00000
#
# decoded input	{
# 	"uint256 n": "201711112",
# 	"string sn": "park",
# 	"bool e": true
# }
#
# decoded output	{}
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# ### ![image.png](attachment:image.png)
# [vm]from: 0x5B3...eddC4to: StudentsCrud.insert(uint256,string,bool) 0x7EF...8CB47value: 0 weidata: 0xf07...00000logs: 0hash: 0xa30...fdf62
#
# status	true Transaction mined and execution succeed
#
# transaction hash	0xa302c5a432c691985b651df7fbdd2a1eda3e26c1a64cb6bded30c05cbcafdf62
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.insert(uint256,string,bool) 0x7EF2e0048f5bAeDe046f6BF797943daF4ED8CB47
#
# gas	108831 gas
#
# transaction cost	94635 gas
#
# execution cost	94635 gas
#
# input	0xf07...00000
#
# decoded input	{
# 	"uint256 n": "201711113",
# 	"string sn": "lee",
# 	"bool e": true
# }
#
# decoded output	{}
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# ### ![image.png](attachment:image.png)
# [vm]from: 0x5B3...eddC4to: StudentsCrud.insert(uint256,string,bool) 0x7EF...8CB47value: 0 weidata: 0xf07...00000logs: 0hash: 0x41a...e4f33
#
# status	true Transaction mined and execution succeed
#
# transaction hash	0x41a10c6b20fab9aa1426e258f0ed7ec286c8c083faa46683970ca837018e4f33
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.insert(uint256,string,bool) 0x7EF2e0048f5bAeDe046f6BF797943daF4ED8CB47
#
# gas	108831 gas
#
# transaction cost	94635 gas
#
# execution cost	94635 gas
#
# input	0xf07...00000
#
# decoded input	{
# 	"uint256 n": "201711114",
# 	"string sn": "lim",
# 	"bool e": true
# }
#
# decoded output	{}
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# ## (2) 2번째 데이터 201711112 제거

# %% [markdown]
# ### ![image.png](attachment:image.png)
# [vm]from: 0x5B3...eddC4to: StudentsCrud.remove(uint256) 0xb27...07c2cvalue: 0 weidata: 0x4cc...00002logs: 0hash: 0xeff...d470d
#
# status	true Transaction mined and execution succeed
#
# transaction hash	0xeff48fb4df915b88b86f53ff06be4f134b225f70af8c7fa0aba9ea3ddccd470d
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.remove(uint256) 0xb27A31f1b0AF2946B7F582768f03239b1eC07c2c
#
# gas	62930 gas
#
# transaction cost	45121 gas
#
# execution cost	45121 gas
#
# input	0x4cc...00002
#
# decoded input	{
# 	"uint256 index": "2"
# }
#
# decoded output	{}
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# ### 2번째 데이터여서 2번 인덱스를 지웠다.

# %% [markdown]
# ## (3) 배열크기 조회 (4개 항목에서 1개가 제거되었으니 3이 출력)

# %% [markdown]
# ### ![image.png](attachment:image.png)
# call to StudentsCrud.getLength
#
# CALL
#
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: StudentsCrud.getLength()data: 0xbe1...c766b
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.getLength() 0x7EF2e0048f5bAeDe046f6BF797943daF4ED8CB47
#
# execution cost	23429 gas (Cost only applies when called by a contract)
#
# input	0xbe1...c766b
#
# decoded input	{}
#
# decoded output	{
# 	"0": "uint256: 3"
# }
#
# logs	[]

# %% [markdown]
# ## (4) 2 번째 데이터조회를 조회한다. 20171112는 삭제되어서 출력할 수 없고, 다른 데이터 항목이 출력.

# %% [markdown]
# ### ![image.png](attachment:image.png)
# call to StudentsCrud.findBy
#
# CALL
#
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: StudentsCrud.findBy(uint8)data: 0xedf...00002
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.findBy(uint8) 0xb27A31f1b0AF2946B7F582768f03239b1eC07c2c
#
# execution cost	31433 gas (Cost only applies when called by a contract)
#
# input	0xedf...00002
#
# decoded input	{
# 	"uint8 index": 2
# }
#
# decoded output	{
# 	"0": "uint256: 201711114",
# 	"1": "string: lim",
# 	"2": "bool: false"
# }
#
# logs	[]

# %% [markdown]
# ### 정말 다른 데이터가 출력된다.

# %% [markdown]
# ## (5) 첫 데이터 조회

# %% [markdown]
# ### ![image.png](attachment:image.png)
# call to StudentsCrud.getFirstStudent
#
# CALL
#
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: StudentsCrud.getFirstStudent()data: 0xacb...e8cee
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	StudentsCrud.getFirstStudent() 0x7EF2e0048f5bAeDe046f6BF797943daF4ED8CB47
#
# execution cost	31138 gas (Cost only applies when called by a contract)
#
# input	0xacb...e8cee
#
# decoded input	{}
#
# decoded output	{
# 	"0": "uint256: 201711111",
# 	"1": "string: kim",
# 	"2": "bool: false"
# }
#
# logs	[]
